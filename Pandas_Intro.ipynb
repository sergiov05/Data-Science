# %%
import pandas as pd

# %%
df = pd.read_csv("Rotten Tomatoes Movies.csv")
df.head()
# Out:
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  A teenager discovers he's the descendant of a ...
# 1  Kate has a lot on her mind. There's the ethics...
# 2  Blake Edwards' 10 stars Dudley Moore as George...
# 3  A Puerto Rican youth is on trial for murder, a...
# 4  This 1954 Disney version of Jules Verne's 20,0...
#
#                                    critics_consensus rating  \
# 0  Though it may seem like just another Harry Pot...     PG
# 1  Nicole Holofcener's newest might seem slight i...      R
# 2                                                NaN      R
# 3  Sidney Lumet's feature debut is a superbly wri...     NR
# ...

# %%
df
# Out:
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# 16633                                          Zoot Suit
# 16634                                           Zootopia
# 16635                                    Zorba the Greek
# 16636                                               Zulu
# 16637                                          Zulu Dawn
#
#                                               movie_info  \
# 0      A teenager discovers he's the descendant of a ...
# 1      Kate has a lot on her mind. There's the ethics...
# 2      Blake Edwards' 10 stars Dudley Moore as George...
# ...

# %%
columns = ["movie_title","genre","studio_name","tomatometer_rating"]
filtered_df = df[columns]

# %%
filtered_df.head()
# Out:
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                                genre             studio_name  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...        20th Century Fox
# 1                                             Comedy  Sony Pictures Classics
# 2                                    Comedy, Romance             Waner Bros.
# 3                                    Classics, Drama    Criterion Collection
# 4           Action & Adventure, Drama, Kids & Family                  Disney
#
#    tomatometer_rating
# 0                  49
# 1                  86
# 2                  68
# 3                 100
# 4                  89

# %%
type(df.iloc[500])
# Out:
# pandas.core.series.Series

# %%
df.iloc[lambda x : x.index % 2 != 0]
# Out:
#                            movie_title  \
# 1                          Please Give
# 3      12 Angry Men (Twelve Angry Men)
# 5                          10,000 B.C.
# 7                         3:10 to Yuma
# 9                      Abraham Lincoln
# ...                                ...
# 16629                        Zookeeper
# 16631                      Zoolander 2
# 16633                        Zoot Suit
# 16635                  Zorba the Greek
# 16637                        Zulu Dawn
#
#                                               movie_info  \
# 1      Kate has a lot on her mind. There's the ethics...
# 3      A Puerto Rican youth is on trial for murder, a...
# 5      A young outcast from a primitive tribe is forc...
# 7      Desperate for money, frontier rancher Van Hefl...
# 9      To date, this D.W. Griffith epic is the only t...
# ...                                                  ...
# 16629  In Zookeeper, the animals at the Franklin Park...
# ...

# %%
df.loc["tomatometer_status" == "Fresh"]
# Out:
#                             movie_title  \
# 2                                    10
# 4          20,000 Leagues Under The Sea
# 7                          3:10 to Yuma
# 9                       Abraham Lincoln
# 10                           Dark Water
# ...                                 ...
# 16627  ZMD: Zombies of Mass Destruction
# 16628                               Zoo
# 16630                         Zoolander
# 16635                   Zorba the Greek
# 16636                              Zulu
#
#                                               movie_info  \
# 2      Blake Edwards' 10 stars Dudley Moore as George...
# 4      This 1954 Disney version of Jules Verne's 20,0...
# 7      Desperate for money, frontier rancher Van Hefl...
# 9      To date, this D.W. Griffith epic is the only t...
# 10     Following up on his horror smash hits Ringu an...
# ...                                                  ...
# 16627  A small town wrestling with xenophobia is forc...
# ...

# %%
counted_df = df[["movie_title","tomatometer_status"]].groupby(by="tomatometer_status").count()

# %%
counted_df
# Out:
#                     movie_title
# tomatometer_status
# Certified Fresh            2957
# Fresh                      6448
# Rotten                     7233

# %%
values = counted_df.values

# %%
type(values_list)
# Out:
# list

# %%
index = counted_df.index

# %%
values_list = []
for i in values:
    for j in i:
        values_list.append(j)

# %%
plt.bar(index,values_list)
# Out:
# <BarContainer object of 3 artists>

# %%
df[["movie_title","tomatometer_status"]].groupby(by="tomatometer_status").count()
# Out:
#                     movie_title
# tomatometer_status
# Certified Fresh            2957
# Fresh                      6448
# Rotten                     7233

# %%
df[["studio_name","audience_rating"]].groupby(by="studio_name").mean().sort_values(by="audience_rating",ascending=False)
# Out:
#                                  audience_rating
# studio_name
# Milestone Films                            100.0
# NEON/Hulu                                  100.0
# HBO Sports                                 100.0
# Big Mouth Productions                      100.0
# Shadowbox Films                            100.0
# ...                                          ...
# Warner Bros. Home Entertainment              NaN
# Warner Brothers Classics                     NaN
# Well Go USA Inc.                             NaN
# WigglyWorld Studios                          NaN
# Zentropa Entertainments                      NaN
#
# [2886 rows x 1 columns]

# %%
cleaned_df = df.dropna()

# %%
df.describe()
# Out:
#        runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# count        16483.000000        16638.000000       16638.000000
# mean           102.391494           60.466522          56.607104
# std             25.028011           28.587230          66.383800
# min              1.000000            0.000000           5.000000
# 25%             90.000000           38.000000          12.000000
# 50%             99.000000           66.000000          28.000000
# 75%            111.000000           86.000000          76.000000
# max           2000.000000          100.000000         497.000000
#
#        audience_rating  audience_count
# count     16386.000000    1.638600e+04
# mean         60.470829    1.524797e+05
# std          20.462368    1.817736e+06
# min           0.000000    5.000000e+00
# 25%          45.000000    8.642500e+02
# 50%          62.000000    4.876500e+03
# 75%          77.000000    2.875200e+04
# max         100.000000    3.579764e+07

# %%
cleaned_df
# Out:
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# 5                                            10,000 B.C.
# ...                                                  ...
# 16629                                          Zookeeper
# 16630                                          Zoolander
# 16631                                        Zoolander 2
# 16632                                               Zoom
# 16634                                           Zootopia
#
#                                               movie_info  \
# 0      A teenager discovers he's the descendant of a ...
# 1      Kate has a lot on her mind. There's the ethics...
# 3      A Puerto Rican youth is on trial for murder, a...
# ...

# %%
cleaned_df[["studio_name","audience_rating"]].groupby(by="studio_name").mean().sort_values(by="audience_rating",ascending=False)
# Out:
#                              audience_rating
# studio_name
# NEON/Hulu                              100.0
# CiBy 2000                               96.0
# Home Vision Entertainment               96.0
# Satyajit Ray Productions                95.0
# Liberty Films                           95.0
# ...                                      ...
# AMBI Media Group                        16.0
# Chubbco Film Co.                        16.0
# Wrekin Hill                             15.0
# MGM/UA Distribution Company             14.0
# Pelican Point Media                     12.0
#
# [1119 rows x 1 columns]

# %%
df.iloc[16633]
# Out:
# movie_title                                                   Zoot Suit
# movie_info            Based on a 1940s Los Angeles murder trial, thi...
# critics_consensus                                                   NaN
# rating                                                                R
# genre                                  Drama, Musical & Performing Arts
# directors                                                   Luis Valdez
# writers                                                     Luis Valdez
# cast                  Daniel Valdez, Edward James Olmos, Charles Aid...
# in_theaters_date                                             1981-10-02
# on_streaming_date                                            2003-05-27
# runtime_in_minutes                                                104.0
# studio_name                                    MCA Universal Home Video
# tomatometer_status                                               Rotten
# ...
